# %% [markdown]
# # Scratch work for developing initial src/data/pipeline.py

# %%
import pandas as pd
from data.pipeline import build_item_store_day

# %%
raw_data_fp = "../data/raw"
sales_train_validation = pd.read_csv(
    f"{raw_data_fp}/sales_train_validation.csv"
)
calendar = pd.read_csv(
    f"{raw_data_fp}/calendar.csv"
)
sell_prices = pd.read_csv(
    f"{raw_data_fp}/sell_prices.csv"
)

# %%
item_store_day_new = build_item_store_day(
    sales_train_validation,
    calendar,
    sell_prices,
)

# %%
item_store_day_reference = pd.read_parquet(
    "../data/processed/item_store_day.parquet"
)

# %% [markdown]
# #### Validate that newly created `item_store_day` is identical to the persisted parquet one we originally created in `02_data_pipeline.ipynb`

# %%
# Check shape
item_store_day_new.shape == item_store_day_reference.shape
# Out:
# True

# %%
# Check column order
item_store_day_new.columns.tolist() == item_store_day_reference.columns.tolist()
# Out:
# True

# %%
# Check dtypes
item_store_day_new.dtypes.equals(item_store_day_reference.dtypes)
# Out:
# True

# %%
# Now we know the basic structure matches
# Compare the actual data
item_store_day_new.equals(item_store_day_reference)
# Out:
# True

# %%
# Everything looks good so far
# Double-check the functions output directly to make sure nothing weird happened during the comparison
item_store_day_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58327370 entries, 0 to 58327369
# Data columns (total 8 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   item_id        object
#  1   store_id       object
#  2   d              int64
#  3   date           datetime64[ns]
#  4   wm_yr_wk       int64
#  5   units_sold     int64
#  6   sell_price     float64
#  7   daily_revenue  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 3.5+ GB

# %% [markdown]
# Output is as expected:
# - 58,327,370 rows
# - 8 columns
# - all expected dtypes
# - ~3.5 GB in memory
# - and, importantly, it is identical to the existing validated Parquet.
